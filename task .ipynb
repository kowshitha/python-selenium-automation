# %%
import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import Select
import time
import pandas as pd

# %%
#image task

# %%
import os
os.getcwd()
os.chdir(r"C:\Users\merit\images")

# %%
import os
driverpath=r"C:\Users\merit\Downloads\chromedriver_win32\chromedriver.exe"
driver=webdriver.Chrome(executable_path=driverpath)
driver.get("https://www.cricbuzz.com/cricket-team")
country=driver.find_elements_by_xpath("//body/div[1]/div[2]/div[5]/div[1]")
l= []
for i in country:
    l.append(i.text)
    l1=l[0].split('\n')
    print("Country name:",l1)
img=driver.find_elements_by_xpath("//div[contains(@class,'cb-col cb-col-25')]")
for i,j in zip(img,l1):    
    with open(j+".png","wb") as pic:
        pic.write(i.screenshot_as_png)
driver.close
# Out:
# Country name: ['India', 'Ireland', 'Pakistan', 'Australia', 'Sri Lanka', 'Bangladesh', 'England', 'West Indies', 'South Africa', 'Zimbabwe', 'New Zealand', 'Afghanistan', 'Italy', 'Botswana', 'Iran', 'Belgium', 'Denmark', 'Namibia', 'Singapore', 'Bermuda', 'Canada', 'Uganda', 'Malaysia', 'Nepal', 'Netherlands', 'Scotland', 'United Arab Emirates', 'Hong Kong', 'Kenya', 'United States', 'Germany', 'Fiji', 'Kuwait', 'Vanuatu', 'Jersey', 'Oman', 'Papua New Guinea']
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="562bc812d9f1b8c6fe05e74b0175182c")>>

# %%
# ranking task

# %%
import os
os.getcwd()
os.chdir(r"C:\Users\merit\Desktop")

# %%
driverpath=r"C:\Users\merit\Downloads\chromedriver_win32\chromedriver.exe"
driver=webdriver.Chrome(executable_path=driverpath)
driver.get("https://www.cricbuzz.com/")
print(driver.title)
print(driver.current_url)
driver.maximize_window()
fname="batting.xlsx"
writer=pd.ExcelWriter(r"C:\\Users\\merit\\Desktop\\ranking"+"\\"+fname,engine="xlsxwriter")
fname1="bowling.xlsx"
writer1=pd.ExcelWriter(r"C:\\Users\\merit\\Desktop\\ranking"+"\\"+fname1,engine="xlsxwriter")
fname2="all-rounder.xlsx"
writer2=pd.ExcelWriter(r"C:\\Users\\merit\\Desktop\\ranking"+"\\"+fname2,engine="xlsxwriter")
fname3="teams.xlsx"
writer3=pd.ExcelWriter(r"C:\\Users\\merit\\Desktop\\ranking"+"\\"+fname3,engine="xlsxwriter")
cricket=['batsmen','bowlers','all-rounders','teams']
cric=['batsmen','bowlers','allrounders','teams']
Batting = ['tests','odis','t20s']
with open("bat.txt","a") as batting:
        driver.find_element_by_xpath("//div[@id='rankingDropDown']").click()
        time.sleep(2)
        for i in cricket:
            driver.find_element_by_xpath("//a[@id='"+i+"-tab']").click()
            for j in Batting:
                if i=="batsmen":
                    testing=driver.find_element_by_xpath("//a[@id='batsmen-"+j+"-tab']").click()
                    if j =="tests":
                        table=driver.find_elements_by_xpath('//*[@id="page-wrapper"]/div[3]/div[2]/div/div/div[1]/div') 
                        headers=table[0].text.split('\n')
                        columns = dict()
                        for h1 in headers:
                            columns[h1] = []
                        for rw in table[1:]:
                            data=rw.text.split('\n')
                            dt=data[0]+"@"+data[2]+"@"+data[4]
                            dt1=dt.split("@")
                            for name, item in zip(headers,dt1):
                                value = item
                                columns[name].append(value)
                            pd.DataFrame(columns).to_excel(writer,sheet_name=i+j,index=False)
                    elif j =="odis":
                        table1=driver.find_elements_by_xpath('//*[@id="page-wrapper"]/div[3]/div[2]/div/div/div[2]/div') 
                        headers1=table1[0].text.split('\n')
                        columns = dict()
                        for h1 in headers1:
                            columns[h1] = []
                        for rw in table1[1:]:
                            data=rw.text.split('\n')
                            dt=data[0]+"@"+data[2]+"@"+data[4]
                            dt1=dt.split("@")
                            for name, item in zip(headers1,dt1):
                                value = item
                                columns[name].append(value)
                            pd.DataFrame(columns).to_excel(writer,sheet_name=i+j,index=False)
                    else:
                        table2=driver.find_elements_by_xpath('//*[@id="page-wrapper"]/div[3]/div[2]/div/div/div[3]/div') 
                        headers2=table2[0].text.split('\n')
                        for h1 in headers2:
                            columns[h1] = []
                        for rw in table2[1:]:
                            data=rw.text.split('\n')
                            dt=data[0]+"@"+data[2]+"@"+data[4]
                            dt1=dt.split("@")
                            for name, item in zip(headers2,dt1):
                                value = item
                                columns[name].append(value)
                            pd.DataFrame(columns).to_excel(writer,sheet_name=i+j,index=False)
                            
                elif i=="bowlers":
                    testing=driver.find_element_by_xpath("//a[@id='bowlers-"+j+"-tab']").click() 
                    if j =="tests":
                        table=driver.find_elements_by_xpath('//*[@id="page-wrapper"]/div[3]/div[2]/div/div/div[1]/div') 
                        headers=table[0].text.split('\n')
                        columns = dict()
                        for h1 in headers:
                            columns[h1] = []
                        for rw in table[1:]:
                            data=rw.text.split('\n')
                            dt=data[0]+"@"+data[2]+"@"+data[4]
                            dt1=dt.split("@")
                            for name, item in zip(headers,dt1):
                                value = item
                                columns[name].append(value)
                            pd.DataFrame(columns).to_excel(writer1,sheet_name=i+j,index=False)
                    elif j =="odis":
                        table1=driver.find_elements_by_xpath('//*[@id="page-wrapper"]/div[3]/div[2]/div/div/div[2]/div') 
                        headers1=table1[0].text.split('\n')
                        columns = dict()
                        for h1 in headers1:
                            columns[h1] = []
                        for rw in table1[1:]:
                            data=rw.text.split('\n')
                            dt=data[0]+"@"+data[2]+"@"+data[4]
                            dt1=dt.split("@")
                            for name, item in zip(headers1,dt1):
                                value = item
                                columns[name].append(value)
                            pd.DataFrame(columns).to_excel(writer1,sheet_name=i+j,index=False)
                    else:
                        table2=driver.find_elements_by_xpath('//*[@id="page-wrapper"]/div[3]/div[2]/div/div/div[3]/div') 
                        headers2=table2[0].text.split('\n')
                        for h1 in headers2:
                            columns[h1] = []
                        for rw in table2[1:]:
                            data=rw.text.split('\n')
                            dt=data[0]+"@"+data[2]+"@"+data[4]
                            dt1=dt.split("@")
                            for name, item in zip(headers2,dt1):
                                value = item
                                columns[name].append(value)
                            pd.DataFrame(columns).to_excel(writer1,sheet_name=i+j,index=False)
                            
                elif i=="all-rounders":
                    testing=driver.find_element_by_xpath("//a[@id='allrounders-"+j+"-tab']").click()
                    if j =="tests":
                        table=driver.find_elements_by_xpath('//*[@id="page-wrapper"]/div[3]/div[2]/div/div/div[1]/div') 
                        headers=table[0].text.split('\n')
                        columns = dict()
                        for h1 in headers:
                            columns[h1] = []
                        for rw in table[1:]:
                            data=rw.text.split('\n')
                            dt=data[0]+"@"+data[2]+"@"+data[4]
                            dt1=dt.split("@")
                            for name, item in zip(headers,dt1):
                                value = item
                                columns[name].append(value)
                            pd.DataFrame(columns).to_excel(writer2,sheet_name=i+j,index=False)
                    elif j =="odis":
                        table1=driver.find_elements_by_xpath('//*[@id="page-wrapper"]/div[3]/div[2]/div/div/div[2]/div') 
                        headers1=table1[0].text.split('\n')
                        columns = dict()
                        for h1 in headers1:
                            columns[h1] = []
                        for rw in table1[1:]:
                            data=rw.text.split('\n')
                            dt=data[0]+"@"+data[2]+"@"+data[4]
                            dt1=dt.split("@")
                            for name, item in zip(headers1,dt1):
                                value = item
                                columns[name].append(value)
                            pd.DataFrame(columns).to_excel(writer2,sheet_name=i+j,index=False)
                    else:
                        table2=driver.find_elements_by_xpath('//*[@id="page-wrapper"]/div[3]/div[2]/div/div/div[3]/div') 
                        headers2=table2[0].text.split('\n')
                        for h1 in headers2:
                            columns[h1] = []
                        for rw in table2[1:]:
                            data=rw.text.split('\n')
                            dt=data[0]+"@"+data[2]+"@"+data[4]
                            dt1=dt.split("@")
                            for name, item in zip(headers2,dt1):
                                value = item
                                columns[name].append(value)
                            pd.DataFrame(columns).to_excel(writer2,sheet_name=i+j,index=False)
                                       
                elif i=="teams":
                    testing=driver.find_element_by_xpath("//a[@id='teams-"+j+"-tab']").click()
                    if j =="tests":
                        table=driver.find_elements_by_xpath('//*[@id="page-wrapper"]/div[3]/div[2]/div/div/div[1]/div') 
                        headers=table[1].text.split('\n')
                        columns = dict()
                        for h1 in headers:
                            columns[h1] = []
                        for rw in table[2:]:
                            data=rw.text.split('\n')
                            for name, item in zip(headers,data):
                                value = item
                                columns[name].append(value)
                            pd.DataFrame(columns).to_excel(writer3,sheet_name=i+j,index=False)
                    elif j=="odis":
                        table1=driver.find_elements_by_xpath('//*[@id="page-wrapper"]/div[3]/div[2]/div/div/div[2]/div') 
                        headers1=table1[0].text.split('\n')
                        columns = dict()
                        for h1 in headers1:
                            columns[h1] = []
                        for rw in table1[1:]:
                            data=rw.text.split('\n')
                            for name, item in zip(headers1,data):
                                value = item
                                columns[name].append(value)
                            pd.DataFrame(columns).to_excel(writer3,sheet_name=i+j,index=False)
                    else:
                        table2=driver.find_elements_by_xpath('//*[@id="page-wrapper"]/div[3]/div[2]/div/div/div[3]/div') 
                        headers2=table2[0].text.split('\n')
                        columns = dict()
                        for h1 in headers2:
                            columns[h1] = []
                        for rw in table2[1:]:
                            data=rw.text.split('\n')
                            for name, item in zip(headers2,data):
                                value = item
                                columns[name].append(value)
                            pd.DataFrame(columns).to_excel(writer3,sheet_name=i+j,index=False)
                
                            
driver.close()
writer.save()
writer.close()
writer1.save()
writer1.close()
writer2.save()
writer2.close()
writer3.save()
writer3.close()
# Out:
# IPL 2021 Cricket Score, Schedule, Latest News, Stats & Videos | Cricbuzz.com
# https://www.cricbuzz.com/

# %%
#states task

# %%
driverpath=r"C:\Users\merit\Downloads\chromedriver_win32\chromedriver.exe"
driver=webdriver.Chrome(executable_path=driverpath)
fname="state.xlsx"
writer=pd.ExcelWriter(r"C:\\Users\\merit\\Desktop"+"\\"+fname,engine="xlsxwriter")
driver.get("https://ai.fmcsa.dot.gov/hhg/Search.asp?ads=a&lan=en")
driver.maximize_window()
driver.find_element_by_xpath("//label[contains(text(),'State :')]//following::select").click()
for i in range(1,97):
    country=driver.find_element_by_xpath("//option[contains(text(),'Please select state')]//following::option["+str(i)+"]")
    country.click()
    con=country.text
    driver.find_element_by_xpath("//tbody/tr[1]/td[2]/input[3]").click()
    table=driver.find_element_by_xpath("//h2[contains(text(),'Search Results')]//following::td[13]")
    try:
        allrows=table.find_elements_by_tag_name("tr")
        h=allrows[0].text.split(" ")
        h1=h[0]+"-"+h[1]+","+h[2]+"-"+h[3]+","+h[4]+"-"+h[5]+","+h[7]+"-"+h[8]
        h2=h1.split(',')
        columns = dict()
        for h in h2:
            columns[h] = []
        for rw in allrows[1:]:
            data = rw.find_elements_by_tag_name("td")
            for name, item in zip(h2,data):
                        value = item.text
                        if value.startswith (" \nNotes"):
                            break
                        else:
                            columns[name].append(value)
            pd.DataFrame(columns).to_excel(writer,sheet_name=con,index=False)
    except:
        pass
        
    driver.back()
driver.close()
writer.save()
writer.close()
